# %% [markdown]
# # Maps with ipyleaflet
#
# More information on [GitHub](https://github.com/jupyter-widgets/ipyleaflet) and [readthedocs](https://ipyleaflet.readthedocs.io/en/latest/usage.html)

# %%
import labInfo2JSON
JSONLABS = '/Users/otto/Documents/GitLab/inframsl/labs.json'
MSL_Labs = labInfo2JSON.loadJSONFromFile(JSONLABS)

# %%
# show JSON (MSL_LABS)
prettyOutput = labInfo2JSON.getJSONPrettyDumpAsString(MSL_Labs)
print(prettyOutput)
# Out:
# {
#     "infrastructures": [
#         {
#             "facility": {
#                 "type": "laboratory",
#                 "lab_id": "6c110ea0c47b7a32bbe553b6da1ce193",
#                 "research_infrastructure_name": "Roma TRE",
#                 "facility_name": "Paleomagnetic Laboratory",
#                 "address": {
#                     "street_with_number": "Lungotevere Danta",
#                     "postal_code": "00146",
#                     "city": "Rome",
#                     "country": "Italy"
#                 },
#                 "gps": {
#                     "gps_lat": 41.854167,
#                     "gps_lon": 12.464444
#                 },
#                 "website": "http://host.uniroma3.it/docenti/mattei/Paleomagnetic_Lab.html",
#                 "lab_services": {
#                     "research_field": "Paleomagnetism",
#                     "subdomain": [
#                         "Paleomagnetic and magnetic data"
#                     ],
# ...

# %%
from ipyleaflet import *
from ipywidgets import Label
import geocoder # currently not used
center = (52.312, 7.647)

m = Map(
    center=(52.312, 7.647),
    zoom=4
)
display(m)

labelMouseOver = Label()
display(labelMouseOver)

def handle_interaction(**kwargs):
    if kwargs.get('type') == 'mousemove':
        labelMouseOver.value = str(kwargs.get('coordinates'))

m.on_interaction(handle_interaction)
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …
# Label(value='')

# %%
for lab in MSL_Labs['infrastructures']:
    lab_location = (lab['facility']['gps']['gps_lat'],lab['facility']['gps']['gps_lon'])
    #print(location)
    tooltip_text = lab['facility']['facility_name'] + '\n' + lab['facility']['address']['city']
    marker = Marker(location=lab_location, draggable=False, title=tooltip_text)
    m.add_layer(marker);

# %%
import pandas as pd

df = pd.read_json(prettyOutput, orient='index')
# View the first ten rows
df.head(10)
# Out:
#                                                                 0   \
# infrastructures  {'facility': {'type': 'laboratory', 'lab_id': ...
#
#                                                                 1   \
# infrastructures  {'facility': {'type': 'laboratory', 'lab_id': ...
#
#                                                                 2   \
# infrastructures  {'facility': {'type': 'laboratory', 'lab_id': ...
#
#                                                                 3   \
# infrastructures  {'facility': {'type': 'laboratory', 'lab_id': ...
#
#                                                                 4   \
# infrastructures  {'facility': {'type': 'laboratory', 'lab_id': ...
#
#                                                                 5   \
# infrastructures  {'facility': {'type': 'laboratory', 'lab_id': ...
#
#                                                                 6   \
# infrastructures  {'facility': {'type': 'laboratory', 'lab_id': ...
# ...
